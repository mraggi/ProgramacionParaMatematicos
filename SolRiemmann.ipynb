# %%
def rect(x,y,w):
    points = [(x,0),(x+w,0),(x+w,y),(x,y)]
    border = line2d(points+[points[0]],color='black',thickness=1)
    return polygon2d(points,color='grey')+border

# %%
def riemmann(f,a,b,n):
    P = plot(f(x),x,a,b)
    dx = (b-a)/n
    X = [a+dx*i for i in range(n)]
    P += sum([rect(x,f(x+dx/2),dx) for x in X])
    return P

# %%
riemmann(cos,-3,3,30).show(dpi=300)
# Out:
# Graphics object consisting of 61 graphics primitives
